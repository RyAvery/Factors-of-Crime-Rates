# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# %matplotlib notebook
# Dependencies and Setup
import os
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
# Import the style from Matplotlib.
from matplotlib import style
# File to Load
spd_arrests_data_to_load = os.path.join('..', 'resources', 'Seattle_PD_Arrests_Data_2021.csv')

# %%
# Reading Seattle_PD_Arrests_Data_2021.csv into a dataframe
spd_arrests_data_df = pd.read_csv(spd_arrests_data_to_load, encoding='cp1252')
pd.set_option('display.max_columns', None)
spd_arrests_data_df.head(10)
# Out:
#   Report Number   Offense ID  Offense Start DateTime    Offense End DateTime  \
# 0   2021-343915  30745312580  12/31/2021 11:00:00 PM  12/31/2021 11:10:00 PM
# 1   2021-343627  30775962669  12/31/2021 04:20:00 PM  01/05/2022 01:59:00 AM
# 2   2021-343627  30745245316  12/31/2021 04:20:00 PM  12/31/2021 05:20:00 PM
# 3   2021-343868  30745249159  12/31/2021 10:07:00 PM                     NaN
# 4   2021-343853  30770043208  12/31/2021 10:03:00 PM  12/31/2021 11:00:00 PM
# 5   2021-343817  30762799072  12/31/2021 08:50:00 PM  01/03/2022 01:43:00 PM
# 6   2021-343817  30744376331  12/31/2021 08:50:00 PM  12/31/2021 08:55:00 PM
# 7   2021-343619  30744296573  12/31/2021 05:15:00 PM                     NaN
# 8   2021-343830  30744275906  12/31/2021 12:00:00 AM  12/31/2021 12:00:00 AM
# 9   2021-343694  32551745883  12/31/2021 06:56:00 PM                     NaN
#
#           Report DateTime Group A B Crime Against Category  \
# 0  12/31/2021 11:49:21 PM         A               PROPERTY
# ...

# %%
spd_arrests_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71525 entries, 0 to 71524
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Report Number           71525 non-null  object
#  1   Offense ID              71525 non-null  int64
#  2   Offense Start DateTime  71262 non-null  object
#  3   Offense End DateTime    52610 non-null  object
#  4   Report DateTime         71525 non-null  object
#  5   Group A B               71525 non-null  object
#  6   Crime Against Category  71525 non-null  object
#  7   Offense Parent Group    71525 non-null  object
#  8   Offense                 71525 non-null  object
#  9   Offense Code            71525 non-null  object
#  10  Precinct                71521 non-null  object
#  11  Sector                  71523 non-null  object
#  12  Beat                    71523 non-null  object
#  13  MCPP                    71525 non-null  object
# ...

# %%
spd_arrests_data_df.count()
# Out:
# Report Number             71525
# Offense ID                71525
# Offense Start DateTime    71262
# Offense End DateTime      52610
# Report DateTime           71525
# Group A B                 71525
# Crime Against Category    71525
# Offense Parent Group      71525
# Offense                   71525
# Offense Code              71525
# Precinct                  71521
# Sector                    71523
# Beat                      71523
# MCPP                      71525
# 100 Block Address         66358
# Longitude                 71525
# Latitude                  71525
# dtype: int64
