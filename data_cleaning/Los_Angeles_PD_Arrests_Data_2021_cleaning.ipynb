# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# %matplotlib notebook
# Dependencies and Setup
import os
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
# Import the style from Matplotlib.
from matplotlib import style
# File to Load
lapd_arrests_data_to_load = os.path.join('..', 'resources', 'OLD', 'Los_Angeles_PD_Arrest_Data_2020_to_Present.csv')

# %%
# Reading Los_Angeles_PD_Arrest_Data_2020_to_Present.csv into a dataframe
lapd_arrests_data_df = pd.read_csv(lapd_arrests_data_to_load, encoding='cp1252', converters={'Time': str})
lapd_arrests_data_df.head(1)
# Out:
#    Report ID Report Type             Arrest Date  Time  Area ID    Area Name  \
# 0  211517634         RFC  11/16/2021 12:00:00 AM  0830       15  N Hollywood
#
#    Reporting District  Age Sex Code Descent Code  ...  \
# 0                1535   57        M            W  ...
#
#        Disposition Description     Address Cross Street      LAT       LON  \
# 0  MISDEMEANOR COMPLAINT FILED  LANKERSHIM       CALIFA  34.1775 -118.3822
#
#                     Location Booking Date Booking Time  Booking Location  \
# 0  POINT (-118.3822 34.1775)          NaN          NaN               NaN
#
#    Booking Location Code
# 0                    NaN
#
# [1 rows x 25 columns]

# %%
#Formated 'Arrest Date' datetime into day/month/year
lapd_arrests_data_df['Arrest Date'] = pd.to_datetime(lapd_arrests_data_df['Arrest Date'], 
                                                     errors='coerce')
lapd_arrests_data_df['Arrest Date'] = lapd_arrests_data_df['Arrest Date'].dt.strftime('%Y/%m/%d')
#Formated 'Time' datetime into hour:minute
lapd_arrests_data_df['Time'] = pd.to_datetime(lapd_arrests_data_df['Time'], 
                                                   format='%H%M',
                                                   errors='coerce').dt.strftime('%H:%M')
lapd_arrests_data_df.head()
lapd_arrests_data_df.tail()
# Out:
#         Report ID Report Type Arrest Date   Time  Area ID   Area Name  \
# 198731    6489225     BOOKING  2022/10/25  12:50       18   Southeast
# 198732  220221190         RFC  2022/11/30  11:15        2     Rampart
# 198733    6475957     BOOKING  2022/10/03  05:10        3   Southwest
# 198734    6471566     BOOKING  2022/09/26  09:50       17  Devonshire
# 198735    6477132     BOOKING  2022/10/05  10:10        6   Hollywood
#
#         Reporting District  Age Sex Code Descent Code  ...  \
# 198731                1844   59        M            B  ...
# 198732                 245   61        M            H  ...
# 198733                 311   45        M            H  ...
# 198734                1756   25        M            H  ...
# 198735                 666   28        M            W  ...
#
#             Disposition Description                                  Address  \
# 198731       FELONY COMPLAINT FILED   400 E  IMPERIAL                     HY
# ...

# %%
lapd_arrests_data_df['Arrest Datetime'] = lapd_arrests_data_df['Arrest Date'] + ' ' + lapd_arrests_data_df['Time']
lapd_arrests_data_df['Arrest Datetime'] = pd.to_datetime(lapd_arrests_data_df['Arrest Datetime'],
                                                         errors='coerce',
                                                         dayfirst=True,)
 #lapd_arrests_data_df['Datetime'] = lapd_arrests_data_df['Arrest Datetime'].dt.strftime('%d/%m/%Y %H:%M')
lapd_arrests_data_df['Arrest Datetime']
# Out:
# 0        2021-11-16 08:30:00
# 1        2021-09-01 12:30:00
# 2        2022-03-17 08:50:00
# 3        2021-09-20 17:35:00
# 4        2021-07-27 08:50:00
#                  ...
# 198731   2022-10-25 12:50:00
# 198732   2022-11-30 11:15:00
# 198733   2022-10-03 05:10:00
# 198734   2022-09-26 09:50:00
# 198735   2022-10-05 10:10:00
# Name: Arrest Datetime, Length: 198736, dtype: datetime64[ns]

# %%
lapd_arrests_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198736 entries, 0 to 198735
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Report ID                 198736 non-null  int64
#  1   Report Type               198736 non-null  object
#  2   Arrest Date               198736 non-null  object
#  3   Time                      198721 non-null  object
#  4   Area ID                   198736 non-null  int64
#  5   Area Name                 198736 non-null  object
#  6   Reporting District        198736 non-null  int64
#  7   Age                       198736 non-null  int64
#  8   Sex Code                  198736 non-null  object
#  9   Descent Code              198736 non-null  object
#  10  Charge Group Code         182953 non-null  float64
#  11  Charge Group Description  182922 non-null  object
#  12  Arrest Type Code          198735 non-null  object
# ...

# %%
lapd_arrests_data_2021_df = lapd_arrests_data_df.loc[(lapd_arrests_data_df['Arrest Datetime']>='2021/01/01') & 
                                                     (lapd_arrests_data_df['Arrest Datetime']<='2021/12/31'), 
                                                     ['Report ID', 'Arrest Datetime', 'Arrest Date', 'Time', 'Age',
                                                      'Sex Code', 'Charge Group Description', 'Charge Description', 
                                                      'Address', 'Cross Street', 'LAT', 'LON', 'Location']].sort_values(by='Arrest Datetime').copy()
lapd_arrests_data_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66715 entries, 70899 to 153958
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Report ID                 66715 non-null  int64
#  1   Arrest Datetime           66715 non-null  datetime64[ns]
#  2   Arrest Date               66715 non-null  object
#  3   Time                      66715 non-null  object
#  4   Age                       66715 non-null  int64
#  5   Sex Code                  66715 non-null  object
#  6   Charge Group Description  61451 non-null  object
#  7   Charge Description        61458 non-null  object
#  8   Address                   66715 non-null  object
#  9   Cross Street              34127 non-null  object
#  10  LAT                       66715 non-null  float64
#  11  LON                       66715 non-null  float64
#  12  Location                  66715 non-null  object
# ...

# %%
pd.set_option('display.max_columns', None)
lapd_arrests_data_2021_df.reset_index(drop=True, inplace=True)
lapd_arrests_data_2021_df.head(10)
# Out:
#    Report ID     Arrest Datetime Arrest Date   Time  Age Sex Code  \
# 0  211404904 2021-01-01 00:01:00  2021/01/01  00:01   30        F
# 1    6091402 2021-01-01 00:05:00  2021/01/01  00:05   31        M
# 2  211404620 2021-01-01 00:05:00  2021/01/01  00:05   63        M
# 3    6091579 2021-01-01 00:05:00  2021/01/01  00:05   34        M
# 4    6091474 2021-01-01 00:05:00  2021/01/01  00:05   44        M
# 5    6091432 2021-01-01 00:08:00  2021/01/01  00:08   31        M
# 6    6091459 2021-01-01 00:17:00  2021/01/01  00:17   27        M
# 7    5937059 2021-01-01 00:30:00  2021/01/01  00:30   34        F
# 8  211404609 2021-01-01 00:30:00  2021/01/01  00:30   34        F
# 9    5886873 2021-01-01 00:30:00  2021/01/01  00:30   22        M
#
#          Charge Group Description                          Charge Description  \
# 0                             NaN                                         NaN
# 1  Miscellaneous Other Violations                  LOS ANGELES MUNICIPAL CODE
# ...

# %%
#Renaming columns to make more uniform
lapd_arrests_data_2021_df = lapd_arrests_data_2021_df.rename(columns={'Time':'Arrest Time',
                                                                     'Sex Code':'Sex',
                                                                     'Charge Group Description':'Charge Group',
                                                                     'Cross Street':'Street',
                                                                     'LAT':'Lat',
                                                                     'LON':'Lon',
                                                                     'Location':'Coords'})

# %%
lapd_arrests_data_2021_df.columns
# Out:
# Index(['Report ID', 'Arrest Datetime', 'Arrest Date', 'Arrest Time', 'Age',
#        'Sex', 'Charge Group', 'Charge Description', 'Address', 'Street', 'Lat',
#        'Lon', 'Coords'],
#       dtype='object')

# %%
Los_Angeles_PD_Arrests_Data_2021_semiclean_csv = os.path.join('resources', 'Los_Angeles_PD_Arrest_Data_2021_semiclean.csv')
lapd_arrests_data_2021_df.to_csv(Los_Angeles_PD_Arrests_Data_2021_semiclean_csv, index=False, encoding='ISO=8859-1')
