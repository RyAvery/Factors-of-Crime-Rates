# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# %matplotlib notebook
# Dependencies and Setup
import os
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
# Import the style from Matplotlib.
from matplotlib import style
# File to Load
sfpd_arrests_data_to_load = os.path.join('..', 'resources', 'San_Francisco_PD_Arrests_Data_2021.csv')

# %%
# Reading San_Francisco_PD_Arrests_Data_2021.csv into a dataframe
sfpd_arrests_data_df = pd.read_csv(sfpd_arrests_data_to_load, encoding='cp1252')
pd.set_option('display.max_columns', None)
sfpd_arrests_data_df.head(10)
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 1  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 2  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 3  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 4  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 5  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 6  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 7  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 8  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
# 9  2021/01/01 12:00:00 AM    2021/01/01         00:00           2021
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0               Friday  2021/07/30 09:37:00 PM  105753306374      1057533
# ...

# %%
sfpd_arrests_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128653 entries, 0 to 128652
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Incident Datetime        128653 non-null  object
#  1   Incident Date            128653 non-null  object
#  2   Incident Time            128653 non-null  object
#  3   Incident Year            128653 non-null  int64
#  4   Incident Day of Week     128653 non-null  object
#  5   Report Datetime          128653 non-null  object
#  6   Row ID                   128653 non-null  int64
#  7   Incident ID              128653 non-null  int64
#  8   Incident Number          128653 non-null  int64
#  9   CAD Number               100950 non-null  float64
#  10  Report Type Code         128653 non-null  object
#  11  Report Type Description  128653 non-null  object
#  12  Filed Online             24074 non-null   object
# ...

# %%
sfpd_arrests_data_df.count()
# Out:
# Incident Datetime          128653
# Incident Date              128653
# Incident Time              128653
# Incident Year              128653
# Incident Day of Week       128653
# Report Datetime            128653
# Row ID                     128653
# Incident ID                128653
# Incident Number            128653
# CAD Number                 100950
# Report Type Code           128653
# Report Type Description    128653
# Filed Online                24074
# Incident Code              128653
# Incident Category          128500
# Incident Subcategory       128500
# Incident Description       128653
# Resolution                 128653
# Intersection               122025
# CNN                        122025
# Police District            128653
# Analysis Neighborhood      122007
# Supervisor District        122025
# Latitude                   122025
# Longitude                  122025
# Point                      122025
# dtype: int64
